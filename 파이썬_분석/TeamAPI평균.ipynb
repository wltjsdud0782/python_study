# %%
import pandas as pd

# %%
team_df = pd.read_csv('TeamAPI.csv')
team_df
# Out:
#                데이터 시간         시리얼번호 미세먼지 (㎍/㎥) 초미세먼지 (㎍/㎥) 이산화탄소 (ppm)  \
# 0     2024-03-20 9:59  ICW0W2100488         36          13         365
# 1     2024-03-20 9:59  ICW0W2100506          0           0          95
# 2     2024-03-14 9:08  ICW0W2100587         55          20         392
# 3     2024-03-20 9:59  ICW0W2100582         27          10         608
# 4     2024-03-20 9:59  ICW0W2100579         20           8           0
# ..                ...           ...        ...         ...         ...
# 434  2024-03-21 13:58  ICW0W2100506         32          12          59
# 435   2024-03-14 9:08  ICW0W2100587         55          20         392
# 436  2024-03-21 13:58  ICW0W2100582         30          11         583
# 437  2024-03-21 13:58  ICW0W2100579         11           4           0
# 438  2024-03-21 13:59  ICW0W2100562         26          14         596
#
#     휘발성유기화합물 (ppb) 온도(℃) 습도(%) 소음(dB) 통합실내지수
# 0               36  19.5    15     72     93
# ...

# %%
team_df.iloc[0:,2:10]
# Out:
#     미세먼지 (㎍/㎥) 초미세먼지 (㎍/㎥) 이산화탄소 (ppm) 휘발성유기화합물 (ppb) 온도(℃) 습도(%) 소음(dB)  \
# 0           36          13         365             36  19.5    15     72
# 1            0           0          95              5  10.9    28     59
# 2           55          20         392           6000  24.8    23     69
# 3           27          10         608            261  23.2    19     69
# 4           20           8           0            131  25.3    13     58
# ..         ...         ...         ...            ...   ...   ...    ...
# 434         32          12          59             10    22    14     55
# 435         55          20         392           6000  24.8    23     69
# 436         30          11         583             55  22.7    19     66
# 437         11           4           0            215  25.9    12     63
# 438         26          14         596            493  24.5    14     61
#
#     통합실내지수
# 0       93
# 1       92
# 2       62
# 3       89
# 4       92
# ..     ...
# ...

# %%
len(team_df)
# Out:
# 439

# %%
team_df['온도(℃)']
# Out:
# 0      19.5
# 1      10.9
# 2      24.8
# 3      23.2
# 4      25.3
#        ...
# 434      22
# 435    24.8
# 436    22.7
# 437    25.9
# 438    24.5
# Name: 온도(℃), Length: 439, dtype: object

# %%
team_sum = 0.0
valueList=[]
for key in team_df:
    if key == '온도(℃)':
        valueList.append(team_df[key][:]) # ??????????????????????????????????????????????????
avg = sum(valueList) / len(team_df)
avg
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File c:\Users\GRS\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\ops\array_ops.py:218, in _na_arithmetic_op(left, right, op, is_cmp)
#     217 try:
# --> 218     result = func(left, right)
#     219 except TypeError:
#
# File c:\Users\GRS\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\computation\expressions.py:242, in evaluate(op, a, b, use_numexpr)
#     240     if use_numexpr:
#     241         # error: "None" not callable
# --> 242         return _evaluate(op, op_str, a, b)  # type: ignore[misc]
#     243 return _evaluate_standard(op, op_str, a, b)
#
# File c:\Users\GRS\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\computation\expressions.py:73, in _evaluate_standard(op, op_str, a, b)
#      72     _store_test_result(False)
# ---> 73 return op(a, b)
#
# ...

# %%
team_df['온도 평균'] = (team_df['온도(℃)'])
